# %%
# %python
import requests

mobile_os_usage = requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")

# %%
#below code got error message as "ExecutionError: Public DBFS root is disabled. Access is denied on path: /usage_metrics". So used following fix

# %%
dbutils.fs.put("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",mobile_os_usage.text,overwrite=True)
